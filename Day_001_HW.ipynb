# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
def mean_squared_error(y, y_hat):
    sub = y-y_hat
    np_len = sub.size
    return np.sum(np.power(sub, 2))/np_len

def mean_absolute_error(y, y_hat):
    sub = y-y_hat
    np_len = sub.size
    return np.sum(np.absolute(sub))/np_len
    return

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 199.683
# The Mean absolute error is 11.027

# %%
# 作業一
# 1.1 瞭解臺灣旅遊人口結構
# 1.2 從觀光局取得
# 1.3 表格
# 1.4 歸類法 (目前找到的資料很多都非完整面向的資料，同一議題不同面向的資料不容易取得，有點難整理出好的問題，反之亦然)

# %%
# 作業二
# 2.1 如何提昇客戶滿意度
# 2.2 提供點選滿意度之面板(不完整，為免影響客戶服務體驗，問題不可太多 or 太難 or 太雜)，
#     或是透過叫車 App傳送客戶服務滿意度回函(更完整，某些資訊能從客基本資訊取得，由於是 App 形式，甚至能有地方讓客戶填入非選擇題形式的回答)
# 2.3 表格
# 2.4 ... (這個問題目前真的看不太懂，或許因為我現在還在專注在『資料蒐集』的面向)
